# %%
from collections import defaultdict

# %%
facts = defaultdict(set)
count = 0
f=0
m=0
n=0
with open("списки_весенний_бал_fm.csv") as ff:
    for i in ff.readlines()[1:]:
        count += 1
        ii = i.rstrip().split(';')
        if ii[0] == 'f':
            f = f + 1
        elif ii[0] == 'm':
            m = m + 1
        elif ii[0] == '?':
            n = n + 1
        facts[ii[4]].add(' '.join(filter(None, ii[:-1])))
print(count, m, f, n)
# Out:
# 772 328 442 2

# %%
sorted(list(facts.keys()))
# Out:
# ['БТФ',
#  'БФ',
#  'Био',
#  'Биологический',
#  'Биотех',
#  'Биотехнологический',
#  'Биофак',
#  'Бф',
#  'ВМК',
#  'ВМК МГУ',
#  'ВМиК',
#  'ВМк',
#  'ВШГА',
#  'ВШГАДМИН',
#  'ВШГАуд',
#  'ВШП',
#  'ВШССН',
#  'ВШТ',
#  'Вмк',
#  'Вшссн',
#  'Высшая школа культурной политики и управления в гуманитарной сфере',
#  'Географ',
#  'Географический',
#  'Геологический',
#  'Геофак',
#  'Глобальных процессов',
#  'Государственного управления',
#  'Журналистика',
#  'Журналистики',
#  'Журналистка',
#  'Институт русского языка',
#  'Исаа',
#  'Искусств',
#  'Ист',
#  'Исторический',
#  'Истфак',
#  'ММФ',
#  'МП',
#  'Мех-мат',
#  'МехМат',
#  'Механики-математический',
#  'Механико-математический',
#  'Механико-математический факультет',
#  'Мехмат',
#  'Мировой политики',
#  'НИ мех',
#  'НИИ механики',
#  'Полит',
#  'Политологии',
#  'Политология',
#  'Почв',
#  'Почва',
#  'Почвовведения',
#  'Почвоведение',
#  'Почвоведения',
#  'Психологии',
#  'Психологический',
#  'Психфак',
# ...

# %%
len(list(facts.keys()))
# Out:
# 159

# %%
def popper(names):
    global facts
    for name in names[1:]:
        facts[names[0]]=facts[names[0]].union(facts[name])
        print(facts.pop(name))
    return sum(len(facts[i]) for i in facts)

# %%
popper([])
# Out:
# 772

# %% [markdown]
# +'БТФ'
# +'БФ'
# +'Био'
# +'Биологический'
# +'Биотех'
# +'Биотехнологический'
# +'Биофак'
# +'Бф'
#
# +'биологич'
# +'биологический'
# +'биотех'
# +'биофак'
# +'бф'

# %%
popper(['Биологический', 'Био', 'Биофак', 'Бф', 'БФ', 'биологич', 'биологический', 'биофак', 'бф'])
# Out:
# {'f Лос Аркос Уварова София - Био'}
# {'f Ласкина Татьяна Александровна Биофак', 'f Холькина Арина Алексеевна Биофак', 'f Смешнова Дарья Сергеевна Биофак'}
# {'f Погостина Дарья Денисовна Бф'}
# {'f Судьина Анастасия Константиновна БФ', 'f Бикмурзина Фаина Дмитриевна БФ'}
# {'m Неверов Константин Викторович биологич'}
# {'f Шелепова Виктория Константиновна биологический', 'm Фокичев Николай Сергеевич биологический', 'f Павлюченкова Анастасия Никитична биологический', 'f Надолинская Нонна Игоревна биологический'}
# {'f Загирова Диана Рамазановна биофак', 'f Толстолужинская Анастасия Евгеньевна биофак', 'f Пчелинцева Полина Вячеславовна биофак', 'f Гречневикова Дарья Денисовна биофак', 'f Котлярова Елизавета Владимировна биофак'}
# {'m Берестень Станислав Александрович бф'}
# 772

# %%
popper(['Биотехнологический', 'Биотех', 'БТФ', 'биотех'])
# Out:
# {'m Шадрин Валериан Сергеевич Биотех'}
# {'f Ситникова Дарья Станиславовна БТФ', 'f Смирнова Любава Вячеславовна БТФ', 'f Новикова Наталия Игоревна БТФ'}
# {'f Шошина Олеся Олеговна биотех'}
# 772

# %% [markdown]
# +'ВМК'
# +'ВМК МГУ'
# +'ВМиК'
# +'ВМк'
# +'ВШГА'
# 'ВШГАДМИН'
# 'ВШГАуд'
# +'ВШП'
# +'ВШССН'
# 'ВШТ'
# +'Вмк'
# +'Вшссн'
# 'Высшая школа культурной политики и управления в гуманитарной сфере'
#
# +'вмк'
# +'вшга'
# +'вшп'

# %%
popper(['ВМК', 'ВМК МГУ', 'ВМиК', 'ВМк', 'Вмк', 'вмк'])
# Out:
# {'m Эккоре Николай Дмитриевич ВМК МГУ'}
# {'m Балашов Игорь Олегович ВМиК', 'm Ефремов Денис Валентинович ВМиК'}
# {'m Комаров Юрий Андреевич ВМк'}
# {'m Гаврилов Павел Викторович Вмк', 'm Любич Илья Геннадиевич Вмк', 'm Косов Александр Владимирович Вмк', 'm Кононов Сергей Владиславович Вмк', 'm Будюк Алексей Михайлович Вмк'}
# {'? Нгуен Кхань Кхуен вмк', 'f Окунева Анна Сергеевна вмк', 'f Ниничук Марина Матвеевна вмк', 'm Запутляев Иван Андреевич вмк'}
# 772

# %%
popper(['ВШП', 'вшга'])
# Out:
# {'f Синяткина Вероника Владимировна вшга'}
# 772

# %%
popper(['ВШССН', 'вшп'])
# Out:
# {'f Чекмарева Виктория Николаевна вшп'}
# 772

# %%
popper(['ВШССН', 'Вшссн'])
# Out:
# {'f Томилова Кристина Ильинична Вшссн', 'f Пай Регина Владиславовна Вшссн'}
# 772

# %%
popper(['ВШКПУГС', 'Высшая школа культурной политики и управления в гуманитарной сфере'])
# Out:
# {'m Сагателян Сейран Григорович Высшая школа культурной политики и управления в гуманитарной сфере'}
# 772

# %% [markdown]
# +'Географ'
# +'Географический'
# +'Геологический'
# 'Геофак'
# +'Глобальных процессов'(см. 'фгп')
# +'Государственного управления'(см. 'ФГУ')
# +'Журналистика'
# +'Журналистики'
# +'Журналистка'
#
# +'геогр'
# +'географ'
# +'географический'
# +'геологический'
# +'журналистики'
# +'журфак'

# %%
popper(['Географический', 'Географ', 'геогр', 'географ', 'географический'])
# Out:
# {'f Нестерова Мария Байроновна Географ'}
# {'f Зелихина Светлана Васильевна геогр', 'f Полякова Татьяна Сергеевна геогр', 'f Пахомова Неонилла Генадьевна геогр'}
# {'f Игитова Анастасия Михайловна географ'}
# {'f Лапшина Елена Михайловна географический', 'm Лопатин Андрей Валерьевич географический', 'm Панков Евгений Федорович географический', 'f Семёнова Анастасия Александровна географический', 'm Козлов Михаил Олегович географический', 'm Сорокин Олег Викторович географический', 'm Блинов Денис Викторович географический', 'm Гладкий Антон Сергеевич географический'}
# 772

# %%
popper(['Геологический', 'геологический'])
# Out:
# {'f Искрина Анастасия Витальевна геологический', 'f Торбунова Екатерина Александровна геологический', 'f Нафигуллина Елена Рафаиловна геологический', 'f Русак Александра Андреевна геологический', 'f Толстова Анастасия Ильинична геологический', 'm Сандалов Федор Дмитриевич геологический'}
# 772

# %%
popper(['Журналистики', 'Журналистика', 'Журналистка', 'журналистики', 'журфак'])
# Out:
# {'f Тихонова Анна Сергеевна Журналистика', 'f Попова Софья Владимировна Журналистика', 'f Шахнович Мария Романовна Журналистика'}
# {'f Кугач Александра Ивановна Журналистка'}
# {'f Селезнева Екатерина Борисовна журналистики', 'f Галкина Юлия Сергеевна журналистики', 'f Федосеева Полина Игоревна журналистики', 'f Рацкевич Анастасия Александровна журналистики', 'f Лучкина Дарья Кирилловна журналистики', 'f Кузнецова Эллина Борисовна журналистики'}
# {'f Филиппова Марина Александровна журфак', 'f Шестакова Алина Павловна журфак'}
# 772

# %% [markdown]
# 'Институт русского языка'
# 'Исаа'
# 'Искусств'
# +'Ист'
# +'Исторический'
# +'Истфак'
# +'ММФ'(см. 'Механико-математический')
# 'МП'
#
# +'исторический'
# +'истфак'

# %%
popper(['Исторический', 'Ист', 'Истфак', 'исторический', 'истфак'])
# Out:
# {'f Краснова Елизавета Сергеевнаа Ист'}
# {'f Загора Марина Григорьевна Истфак'}
# {'f Абрашина Татьяна Александровна исторический', 'm Филатов Александр Игоревич исторический', 'm Комин Иван Николаевич исторический', 'm Пономарев Вячеслав Михайлович исторический', 'f Цуканова Виктория Павловна исторический'}
# {'m Жакеньтьев Жак Жакович истфак', 'f Афанасьева Мария Борисовна истфак', 'f Владимирцева Анастасия Сергеевна истфак', 'f Казикова Наталья Александровна истфак'}
# 772

# %% [markdown]
# +'Мех-мат'
# +'МехМат'
# +'Механики-математический'
# +'Механико-математический'
# +'Механико-математический факультет'
# +'Мехмат'
# +'Мировой политики'(см. 'ФМП')
# +'НИ мех'
# +'НИИ механики'
#
# +'мех-мат'
# +'механико-математический'
# +'мехмат'

# %%
popper(['Механико-математический', 'Мех-мат', 'МехМат', 'Механики-математический', 'Механико-математический факультет', 'Мехмат', 'мех-мат', 'механико-математический', 'мехмат', 'ММФ'])
# Out:
# {'m Афанасьев Данил Федорович Мех-мат'}
# {'m Иванов Сергей Викторович МехМат', 'm Васильев Антон Александрович МехМат', 'm Левко Николай Викторович МехМат', 'f Филимонова Дарья Александровна МехМат'}
# {'m Сапунов Кирилл Вячеславович Механики-математический'}
# {'m Шахнович Олег Александрович Механико-математический факультет'}
# ...

# %%
popper(['НИИ механики', 'НИ мех'])
# Out:
# {'m Терауд Валентин Викторович НИ мех'}
# 772

# %% [markdown]
# +'Полит'
# +'Политологии'
# +'Политология'
# +'Почв'
# +'Почва'
# +'Почвовведения'
# +'Почвоведение'
# +'Почвоведения'
#
# +'повчоведения'
# +'политологии'
# +'почва'
# +'почвоведение'
# +'почвоведения'
# +'почвоведнеия'

# %%
popper(['Политологии', 'Полит', 'Политология', 'политологии'])
# Out:
# {'f Пономарева Галина Алексеевна Полит'}
# {'f Зинков Никита Алексеевич Политология', 'f Ярмола Юлия Антоновна Политология', 'm Казарян Давид Геворгович Политология', 'f Недикова Екатерина Тимуровна Политология'}
# {'f Андрейчикова Елизавета Игоревна политологии'}
# 772

# %%
popper(['Почвоведения', 'Почв', 'Почва', 'Почвоведение', 'Почвовведения', 'повчоведения', 'почва', 'почвоведение', 'почвоведения', 'почвоведнеия'])
# Out:
# {'f Костерина Александра Александровна Почв'}
# {'f Волкова Вероника Денисовна Почва', 'f Семенова Арина Владиславовна Почва'}
# {'f Янович Анастасия Сергеевна Почвоведение'}
# {'f Денисова Ольга Евгеньевна Почвовведения'}
# {'f Максимович Александра Валерьевна повчоведения'}
# {'f Мигдисова Ирина Александровна почва', 'f Шакирова Адиля Рустамовна почва', 'f Лунегова Лада Ивановна почва', 'm Николаев Станислав Геннадьевич почва', 'f Бунькова Ольга Михайловна почва', 'f Головлева Юлия Андреевна почва'}
# {'f Бармина Наталья Александровна почвоведение', 'f Шабарова Татьяна Владимировна почвоведение', 'f Чугунова Юлия Геннадиевна почвоведение'}
# {'f Сабирова Рида Владимировна почвоведения', 'f Гончарова Анна Владиславовна почвоведения', 'm Мисик Олег Валерьевич почвоведения', 'f Кистенева Арина Алексеевна почвоведения', 'm Углов Михаил Сергеевич почвоведения'}
# {'f Фортова София Максимовна почвоведнеия'}
# 772

# %% [markdown]
# +'Психологии'
# +'Психологический'
# +'Психфак'
# +'Социологический'
# +'Социология'
# +'Соцфак'
#
# +'психол'
# +'психологии'
# +'психфак'
# 'сотрудник'
# +'социологический'
# +'соцфак'

# %%
popper(['Психологии', 'Психологический', 'Психфак', 'психол', 'психологии', 'психфак'])
# Out:
# {'f Ермошина Юлия Дмитриевна Психологический'}
# {'f Аверченкова Марися Сергеевна Психфак', 'f Горностаева Светлана Игоревна Психфак'}
# {'f Пасынкова Ольга Алксандровна психол'}
# {'f Чудова Елена Станиславовна психологии', 'f Гриднева Екатерина Максимовна психологии', 'f Квардакова Анастасия Владимировна психологии', 'f Миронова Екатерина Александровна психологии', 'f Лебедева Анна Константиновна психологии', 'f Иванова Олеся Алексеевна психологии'}
# {'f Копачевская Мария Андреевна психфак'}
# 772

# %%
popper(['Социологический', 'Социология', 'Соцфак', 'социологический', 'соцфак'])
# Out:
# {'f Полежаева Татьяна Юрьевна Социология'}
# {'f Ефремова Дарья Владимировна Соцфак', 'f Кошелева Анастасия Александровна Соцфак'}
# {'f Сибирякова Юлия Васильевна социологический', 'f Рабенау Татьяна Владимировна социологический'}
# {'f Гончарова Алиса Андреевна соцфак'}
# 772

# %% [markdown]
# +'ФББ'
# +'ФГУ'
# +'ФИЛОСОФСКИЙ'
# +'ФИЯР'
# +'ФКИ'
# +'ФМП'
# +'ФНМ'
# 'ФП'
# +'ФФ'
# +'ФФМ'
# +'ФФФХИ'
# +'ФФХИ'
# +'Факультет фундаментальной медицины'
# +'Фгу'
# 'Физ-хим'
# +'Физический'
# +'Физическиц'
# +'Физфак'
# +'Филологический'
# +'Филос'
# +'Философский'
# +'Филфак'
# +'Фияр'
# +'Фки'
# +'Ффм'
# +'Фффхи'
#
# +'биоинженерии биоинформатики'
#
# +'фбб'
# +'фгп'
# +'фгу'
# +'физический'
# +'физфак'
# +'филол'
# +'филолог'
# +'филологический'
# +'филос'
# +'философский'
# +'филфак'
# +'фияр'
# +'фнм'
# 'французский колледж мгу'
# +'фтлфак'
# +'фф'
# +'ффм'
# +'фффхи'
# +'ффхи'

# %%
popper(['ФББ', 'биоинженерии биоинформатики', 'фбб'])
# Out:
# {'f Трегубова Мария Андреевна биоинженерии биоинформатики'}
# {'f Антоненкова Юлия Станиславовна фбб'}
# 772

# %%
popper(['фгп', 'Глобальных процессов'])
# Out:
# {'m Солдатов Владислав Алексеевич Глобальных процессов'}
# 772

# %%
popper(['ФГУ', 'Фгу', 'фгу', 'Государственного управления'])
# Out:
# {'f Дробышева Екатерина Сергеевна Фгу', 'f Данкова Валерия Владимировна Фгу'}
# {'f Буданова Анастасия Игоревна фгу'}
# {'m Кульчицкий Адриан Юрьевич Государственного управления'}
# 772

# %%
popper(['ФФМ', 'Факультет фундаментальной медицины', 'Ффм', 'ффм'])
# Out:
# {'f Хуцишвили Наталья Андреевна Факультет фундаментальной медицины'}
# {'f Гибадуллина Яна Эркиновна Ффм', 'f Бернер Анастасия Олеговна Ффм', 'f Ларина Екатерина Алексеевна Ффм', 'f Романкова Юлия Евгеньевна Ффм', 'm Назаров Иван Сергеевич Ффм'}
# {'f Паневкина София Владимировна ффм', 'f Сальникова Диана Игоревна ффм', 'f Козлова Александра Олеговна ффм', 'f Ковшова Татьяна Сергеевна ффм', 'f Мельников Никита Алексеевич ффм', 'm Гаджикурбанов Магомед Набигуллаевич ффм', 'f Калашник Анастасия Александровна ффм', 'f Бахчинян Елизавета _ ффм', 'm Хуторной Иван Валерьевич ффм'}
# 772

# %%
popper(['ФФФХИ', 'ФФХИ', 'Фффхи', 'фффхи', 'ффхи'])
# Out:
# {'m Румянцев Егор Владиславович ФФХИ'}
# {'m Сагарадзе Александр Дмитриевич Фффхи', 'm Сайфулин Марсель Жаудатович Фффхи'}
# {'f Тиунова Александра Владимировна фффхи'}
# {'f Коковина Татьяна Сергеевна ффхи'}
# 772

# %%
 popper(['Физический', 'Физическиц', 'Физфак', 'ФФ', 'физический', 'физфак', 'фф'])
# Out:
# {'f Лукашова Татьяна Олеговна Физическиц'}
# {'m Долгов Дмитрий Сергеевич Физфак', 'm Сысоев Илья Дмитриевич Физфак', 'f Каданова Ирина Михайловна Физфак'}
# {'m Муратов Мурат Ильмдарович ФФ'}
# ...

# %%
 popper(['Филологический', 'филол', 'филолог', 'филологический'])
# Out:
# {'f Шарапкова Анастасия Андреевна филол', 'f Черепанова Анастасия Владимировна филол'}
# {'f Окуджава Ирма Мерабиевна филолог', 'f Васильева Татьяна нет филолог'}
# {'m Левиков Георгий Сергеевич филологический', 'f Старцева Полина Сергеевна филологический', 'f Вербина Елена Николаевна филологический', 'f Кременчук Ольга Анатольевна филологический', 'f Гостюнина Анастасия Викторовна филологический', 'f Спиридонова Наталья Сергеевна филологический', 'f Криушина Виктория Михайловна филологический', 'f Разваляева Елизавета Владимировна филологический', 'm Кокорев Георгий Ростиславович филологический', 'f Овчеренко Ульяна Владимировна филологический', 'm Россяйкин Петр Олегович филологический', 'm Яковлев Сергей Владимирович филологический', 'f Максакова Зоя Николаевна филологический', 'f Подофеденко Светлана Анатольевна филологический', 'f Шустрова Софья Сергеевна филологический'}
# 772

# %%
 popper(['Филфак', 'филфак', 'фтлфак'])
# Out:
# {'f Баландина Елена Дмитриевна филфак', 'f Плискунова Екатерина Ильинична филфак', 'f Пунда Александра Сергеевна филфак', 'f Белова Александра Владимировна филфак', 'f Выволокина Дарья Дмитриевна филфак', 'f Матуева Ирина Анатольевна филфак', 'm Сяоин Вэй - филфак', 'f Верещака Наталья Юрьевна филфак', 'f Санталова Анна Сергеевна филфак', 'f Оленикова Анастасия Вячеславовна филфак', 'f Нагорная Мария Александровна филфак', 'f Малявкина Ольга Евгеньевна филфак', 'f Михалева Анна Александровна филфак', 'f Сенилова Александра Сергеевна филфак', 'f Брусова Дарья Олеговна филфак', 'f Пушкина Екатерина Владимировна филфак', 'f Исаева Ульяна Владимировна филфак', 'f Рыбка Мария Станиславовна филфак', 'f Шенгелия Тина Тенгизиевна филфак', 'f Тимофеева Евгения Александровна филфак'}
# {'f Делягина Татьяна Владимировна фтлфак'}
# 772

# %%
 popper(['Философский', 'Филос', 'ФИЛОСОФСКИЙ', 'филос', 'философский'])
# Out:
# {'f Косиченко Каролина Сергеевна Филос'}
# {'f Леонтьева Елена Анатольевна ФИЛОСОФСКИЙ'}
# {'f Вишневецкая Анна - филос', 'f Звездюк Юлия Юрьевна филос'}
# {'m Киселев Михаил Сергеевич философский'}
# 772

# %%
popper(['ФИЯР', 'Фияр', 'фияр'])
# Out:
# {'f Борискина Елизавета Васильевна Фияр', 'f Богачева Анна Андреевна Фияр', 'f Пахрудинова Айшат Магомедовна Фияр', 'f Рыбалова Анна Андреевна Фияр', 'f Морозова Елизавета Дмитриевна Фияр'}
# {'f Постольная Виктория Олеговна фияр', 'f Мамонова Оксана Сергеевна фияр', 'f Мишнова Анна Викторовна фияр'}
# 772

# %%
popper(['ФКИ', 'Фки'])
# Out:
# {'f Мотырева Елена Игоревна Фки'}
# 772

# %%
popper(['ФМП', 'Мировой политики'])
# Out:
# {'m Фарнир Франсуа - Мировой политики'}
# 772

# %%
popper(['ФНМ', 'фнм'])
# Out:
# {'m Моськин Артем Вячеславович фнм'}
# 772

# %% [markdown]
# +'Хим'
# +'Химический'
# +'Химфак'
# +'ЭФ'
# +'Экном'
# +'Эконом'
# +'Экономический'
# +'Экономический факультет'
# +'Юридический'
# +'Юрфак'
#
# +'хим'
# +'химический'
# +'химфак'
# +'хф'
# +'эконом'
# +'экономический'
# +'эф'
# +'юр'
# +'юрид'
# +'юридический'
# +'юрфак'

# %%
popper(['Химический', 'Хим', 'Химфак', 'хим', 'химический', 'химфак', 'хф'])
# Out:
# {'m Варнавский Андрей Николаевич Хим', 'm Фаткулин Артемий Ренатович Хим'}
# {'f Иванченко Анна Васильевна Химфак'}
# {'f Бахтенкова София Евгеньевна хим', 'f Котова Екатерина Юрьевна хим'}
# {'f Гуляева Екатерина Сергеевна химический', 'm Кузнецов Илья Игоревич химический', 'f Запольских Таисия Владимировна химический', 'm Шайдуллин Руслан Радикович химический', 'm Свердлов Юрий Вадимович химический', 'f Урбанович Ксения Георгиевна химический', 'f Дивицкая Дарья Александровна химический'}
# {'f Багдасарян Аида Арутюновна химфак', 'f Аминулла Камилла Гуламовна химфак'}
# {'f Ким Ок-сун Артуровна хф'}
# 772

# %%
popper(['Экономический', 'ЭФ', 'Экном', 'Эконом', 'Экономический факультет', 'эконом', 'экономический', 'эф'])
# Out:
# {'f Митенкова Елена Николаевна ЭФ', 'f Мордвинова Татьяна Дмитриевна ЭФ', 'f Щевьёва Любовь Сергеевна ЭФ'}
# {'f Сафронова Анна Андреевна Экном'}
# {'f Ильиных Анна Владимировна Эконом', 'm Баранов Валентин Николаевич Эконом', 'f Савинкина Василиса Игоревна Эконом', 'f Кривонос Дарья Александровна Эконом', 'f Братишко Алина Александровна Эконом', 'f Гаглоева Ирина Михайловна Эконом', 'm Жуков Матвей Андреевич Эконом', 'f Лозина Ольга Игоревна Эконом'}
# {'m Солоухин Артём Александрович Экономический факультет'}
# {'f Лаврухина Ольга Игоревна эконом', 'f Богомолова Арина Дмитриевна эконом', 'm Олефир Сергей Александрович эконом'}
# {'m Царьков Максим Андреевич экономический', 'm Наумов Иван Андреевич экономический'}
# {'f Брусенина Мария Сергеевна эф', 'f Горовая Ольга Алексеевна эф'}
# 772

# %%
 popper(['Юридический', 'Юрфак', 'юр', 'юрид', 'юридический', 'юрфак'])
# Out:
# {'f Крышевич Марина Валерьевна Юрфак', 'f Сухорукова Диана Вячеславовна Юрфак', 'f Анионова Мария Дмитриевна Юрфак', 'f Роголева Инна Александровна Юрфак', 'm Белов Михаил Сергеевич Юрфак', 'f Васильева Татьяна Станиславовна Юрфак'}
# {'f Якимова Жанна Александровна юр', 'f Базилевская Полина Алексеевна юр'}
# {'f Оваканян Лиана Кимиковна юрид'}
# {'f Ханенко Ирина Олеговна юридический', 'f Мамедова Гюльнара Ханлар кызы юридический', 'f Лапина Полина Сергеевна юридический'}
# {'f Султанова Влада Анатольевна юрфак', 'f Алексеевских Анастасия Евгеньевна юрфак', 'f Григорьева Юлия Николаевна юрфак', 'f Щур Мария Вячеславовна юрфак'}
# 772

# %%
sorted(list(facts.keys()))
# Out:
# ['Биологический',
#  'Биотехнологический',
#  'ВМК',
#  'ВШГА',
#  'ВШГАДМИН',
#  'ВШГАуд',
#  'ВШКПУГС',
#  'ВШП',
#  'ВШССН',
#  'ВШТ',
#  'Географический',
#  'Геологический',
#  'Геофак',
#  'Журналистики',
#  'Институт русского языка',
#  'Исаа',
#  'Искусств',
#  'Исторический',
#  'МП',
#  'Механико-математический',
#  'НИИ механики',
#  'Политологии',
#  'Почвоведения',
#  'Психологии',
#  'Социологический',
#  'ФББ',
#  'ФГУ',
#  'ФИЯР',
#  'ФКИ',
#  'ФМП',
#  'ФНМ',
#  'ФП',
#  'ФФМ',
#  'ФФФХИ',
#  'Физ-хим',
#  'Физический',
#  'Филологический',
#  'Философский',
#  'Филфак',
#  'Химический',
#  'Экономический',
#  'Юридический',
#  'сотрудник',
#  'фгп',
#  'французский колледж мгу']

# %%
len(list(facts.keys()))
# Out:
# 45

# %%
years = defaultdict(set)
count = 0
f=0
m=0
n=0
with open("списки_весенний_бал_fm.csv") as ff:
    for i in ff.readlines()[1:]:
        count += 1
        ii = i.rstrip().split(';')
        if ii[0] == 'f':
            f = f + 1
        elif ii[0] == 'm':
            m = m + 1
        elif ii[0] == '?':
            n = n + 1
        years[ii[5]].add(' '.join(filter(None, ii[:-1])))
print(count, m, f, n)
# Out:
# 772 328 442 2

# %%
sorted(list(years.keys()))
# Out:
# ['1',
#  '2',
#  '3',
#  '4',
#  '5_mag',
#  '5_sp',
#  '6_mag',
#  '6_sp',
#  'аспирант',
#  'выпускник',
#  'сотрудник']

# %%
len(sorted(list(years.keys())))
# Out:
# 11

# %%
def popper(names):
    global years
    for name in names[1:]:
        years[names[0]]=years[names[0]].union(years[name])
        print(years.pop(name))
    return sum(len(years[i]) for i in years)

# %%
 popper(['5', '5_mag', '5_sp'])
# Out:
# {'m Асташенков Михаил Олегович физический', 'm Ургапов Дмитрий Александрович физический', 'f Матуева Ирина Анатольевна филфак', 'f Юдина Дарья Дмитриевна Экономический', 'f Демьянчикова Вера Витальевна ФИЯР', 'm Карпов Владимир Борисович физический', 'm Ермолаев Павел Альбертович ВМК', 'm Рапота Даниил Юрьевич ФФФХИ', 'f Пчелинцева Полина Вячеславовна биофак', 'f Кривонос Дарья Александровна Эконом', 'f Джалилова Джулия Шавкатовна ФКИ', 'f Коваленко Диана Владимировна ВМК', 'f Данкова Валерия Владимировна Фгу', 'm Сотов Александр Сергеевич Мехмат', 'f Шабалина Юлия Андреевна французский колледж мгу', 'm Горев Артем Александрович Географический', 'f Суханова Юлия Сергеевна Биологический', 'f Щевьёва Любовь Сергеевна ЭФ', 'm Пермяков Тимофей Андреевич ВМК', 'f Васильева Татьяна Станиславовна Юрфак', 'm Фролов Михаил Алексеевич Физический', 'f Сабирова Рида Владимировна почвоведения', 'm Ивасенко Роман Дмириевич ВМК', 'm Козловцев Константин Анатольевич ВМК', 'f Баландина Елена Дмитриев
# ...

# %%
 popper(['6', '6_mag', '6_sp'])
# Out:
# {'f Агаджанян Елизавета Георгиевна ВМК', 'f Задорожная Наталия Александровна Геологический', 'f Крючкова Маргарита Олеговна Почвоведения', 'f Холмогорова Мария Сергеевна ВМК', 'm Слепов Павел Сергеевич физический', 'm Сухоручкин Дмитрий Андреевич Физический', 'f Григорян Рузанна Маратовна Экономический', 'm Олефир Сергей Александрович эконом', 'f Шошина Олеся Олеговна биотех', 'm Леменков Даниил Дмитриевич ВМК', 'm Урханов Озон Юрьевич ФФФХИ', 'm Евдокимов Илья Александрович ВМК', 'f Филиппова Марина Александровна журфак', 'f Якимова Жанна Александровна юр', 'm Казарян Давид Геворгович Политология', 'f Кириллова Надежда Олеговна ФИЯР', 'f Буданова Анастасия Игоревна фгу', 'm Солдатов Владислав Алексеевич Глобальных процессов', 'm Бойко Алексей Евгеньевич Геологический', 'f Савинкина Дарья Игоревна ВМК', 'm Эккоре Николай Дмитриевич ВМК МГУ', 'f Русак Александра Андреевна геологический', 'f Романова Виталина Дмитриевна Экономический', 'f Тишина Маргарита Андреевна ФИЯР', 'm Хрульков А
# ...

# %%
sorted(list(years.keys()))
# Out:
# ['1', '2', '3', '4', '5', '6', 'аспирант', 'выпускник', 'сотрудник']

# %%
len(sorted(list(years.keys())))
# Out:
# 9

# %%
import matplotlib.pyplot as plt
from collections import OrderedDict

# %%
def plotter(title, ylabel, facts, axis, name):
    res=[]
    for fact in sorted(facts.keys()):
        res.append((fact, len(facts[fact])))
    
    count=0
    for i,j in sorted(res, key=lambda x: x[1], reverse=True):
        count += j
        print(i, j)
    print(len(facts.keys()))
    print(count)

    #fa = {i:len(j) for i,j in facts.items()}
    fa = defaultdict(lambda: [0, 0, 0])
    for i,k in facts.items():
        for j in k:
            if j.split(' ')[0] == 'm':
                fa[i][0] += 1
            elif j.split(' ')[0] == 'f':
                fa[i][1] += 1
            elif j.split(' ')[0] == '?':
                fa[i][2] += 1
 
    fa=OrderedDict(sorted(fa.items(), key=lambda t: t[0]))
    print(fa)
    print(len(fa.keys()))  
    print(sum(sum(fa[i]) for i in fa))
    
    m = [i[0] for i in fa.values()]
    f = [i[1] for i in fa.values()]
    o = [i[2] for i in fa.values()]
    
    plt.figure(figsize=(15,8))
    p1 = plt.bar(fa.keys(), m)
    p2 = plt.bar(fa.keys(), f, bottom=m)
    p3 = plt.bar(fa.keys(), o, bottom=[x + y for x, y in zip(m, f)])
    plt.xticks(list(fa.keys()), list(fa.keys()), rotation='vertical')
    plt.ylabel(ylabel, size=17)
    plt.title(title, size=17)
    plt.axis(axis)
    plt.legend((p1[0], p2[0], p3[0]), ('Men', 'Women', 'Not known'), fontsize=17, loc=[0.85, 0.8])
    plt.tick_params(labelsize=17)
    #plt.figure(figsize=(10,60))
    #plt.show()
    plt.savefig(name, bbox_inches = 'tight')

# %%
plotter('Распределение участников бала по факультетам', 'Количество участников бала', facts, [-1, 45, 0, 90], 'facts.png')
# Out:
# ВМК 80
# Физический 78
# Механико-математический 74
# Химический 44
# Экономический 40
# Юридический 40
# Биологический 35
# Почвоведения 34
# ФИЯР 32
# Филологический 29
# ФФМ 27
# Географический 25
# Филфак 25
# Исторический 24
# Геологический 20
# ФФФХИ 20
# ФГУ 19
# Журналистики 18
# Психологии 17
# Философский 13
# Политологии 11
# Социологический 11
# Биотехнологический 7
# ФББ 7
# ВШССН 4
# ВШТ 4
# ФКИ 4
# ФМП 4
# ФНМ 4
# ВШГА 3
# ВШП 2
# Геофак 2
# НИИ механики 2
# фгп 2
# ВШГАДМИН 1
# ВШГАуд 1
# ВШКПУГС 1
# Институт русского языка 1
# Исаа 1
# Искусств 1
# МП 1
# ФП 1
# Физ-хим 1
# сотрудник 1
# французский колледж мгу 1
# 45
# 772
# ...

# %%
plotter('Распределение участников бала по курсам', 'Количество участников бала', years, [-1, 9, 0, 120], 'years.png')
# Out:
# 3 116
# 2 112
# выпускник 109
# 1 104
# 4 89
# 5 89
# 6 80
# аспирант 62
# сотрудник 11
# 9
# 772
# OrderedDict([('1', [30, 73, 1]), ('2', [34, 78, 0]), ('3', [38, 78, 0]), ('4', [35, 54, 0]), ('5', [39, 49, 1]), ('6', [34, 46, 0]), ('аспирант', [38, 24, 0]), ('выпускник', [73, 36, 0]), ('сотрудник', [7, 4, 0])])
# 9
# 772
